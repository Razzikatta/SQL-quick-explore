# %%
import pandas as pd

# %%
df = pd.read_csv('dna.csv')

# %%
df.head(2)
# Out:
#    index                         product                    helpful_count  \
# 0      0  Apple iPhone XR (64GB) - Black  5,087 people found this helpful
# 1      1  Apple iPhone XR (64GB) - Black  2,822 people found this helpful
#
#    total_comments                                                url  \
# 0              24  https://www.amazon.in/Apple-iPhone-XR-64GB-Bla...
# 1               6  https://www.amazon.in/Apple-iPhone-XR-64GB-Bla...
#
#   review_country reviewed_at  \
# 0         India   2018-12-12
# 1         India   2018-11-17
#
#                                          review_text       review_rating  \
# 0                                              NOTE:  3.0 out of 5 stars
# 1  Very bad experience with this iPhone xr phone....  1.0 out of 5 stars
#
#   product_company     profile_name  \
# 0           Apple     Sameer Patil
# 1           Apple  Amazon Customer
#
#                                         review_title
# ...

# %%
df_1 = _deepnote_execute_sql('select * from df limit 8', 'SQL_DEEPNOTE_DATAFRAME_SQL')
df_1
# Out:
#    index                         product                    helpful_count  \
# 0      0  Apple iPhone XR (64GB) - Black  5,087 people found this helpful
# 1      1  Apple iPhone XR (64GB) - Black  2,822 people found this helpful
# 2      2  Apple iPhone XR (64GB) - Black  1,798 people found this helpful
# 3      3  Apple iPhone XR (64GB) - Black  1,366 people found this helpful
# 4      4  Apple iPhone XR (64GB) - Black    536 people found this helpful
# 5      5  Apple iPhone XR (64GB) - Black    313 people found this helpful
# 6      6  Apple iPhone XR (64GB) - Black    189 people found this helpful
# 7      7  Apple iPhone XR (64GB) - Black    164 people found this helpful
#
#    total_comments                                                url  \
# 0              24  https://www.amazon.in/Apple-iPhone-XR-64GB-Bla...
# 1               6  https://www.amazon.in/Apple-iPhone-XR-64GB-Bla...
# 2               0  https://www.amazon.in/Apple-iPhone-XR-64GB-Bla...
# ...

# %%
df_2 = _deepnote_execute_sql('select review_country,\n       count(total_comments)\nfrom df\ngroup by 1\norder by 2 desc', 'SQL_DEEPNOTE_DATAFRAME_SQL')
df_2
# Out:
#   review_country  count(total_comments)
# 0         India                    5010

# %% [markdown]
# All reviews are from one country, Total quantity 5K.

# %%
df_4 = _deepnote_execute_sql('select count(distinct product) from df', 'SQL_DEEPNOTE_DATAFRAME_SQL')
df_4
# Out:
#    count(DISTINCT product)
# 0                        1

# %% [markdown]
# All reviews are on 1 product.

# %%
df_5 = _deepnote_execute_sql('select review_rating,\n        count(*)\nfrom df\ngroup by 1\norder by 2 desc', 'SQL_DEEPNOTE_DATAFRAME_SQL')
df_5
# Out:
#         review_rating  count_star()
# 0  5.0 out of 5 stars          3731
# 1  4.0 out of 5 stars           720
# 2  1.0 out of 5 stars           319
# 3  3.0 out of 5 stars           153
# 4  2.0 out of 5 stars            87

# %% [markdown]
# rating on a scale 1-5/5, vast majority is a 5/5 review.

# %%
df_5 = _deepnote_execute_sql('select  \n        round(avg(case when review_rating= \'5.0 out of 5 stars\' then 1\nelse 0 end), 2) AS high_review\nfrom df\n', 'SQL_DEEPNOTE_DATAFRAME_SQL')
df_5
# Out:
#    high_review
# 0         0.74

# %% [markdown]
# These 5/5 reviews represent 0.74 of the total amount.

# %%
df_6 = _deepnote_execute_sql('select \n                round(avg(case when review_rating= \'5.0 out of 5 stars\' then 5\n                when review_rating= \'4.0 out of 5 stars\' then 4\n                when review_rating= \'3.0 out of 5 stars\' then 3\n                when review_rating= \'2.0 out of 5 stars\' then 2\n                when review_rating= \'1.0 out of 5 stars\' then 1    \n                end), 1)\nfrom df', 'SQL_DEEPNOTE_DATAFRAME_SQL')
df_6
# Out:
#    round(avg(CASE  WHEN ((review_rating = '5.0 out of 5 stars')) THEN (5) WHEN ((review_rating = '4.0 out of 5 stars')) THEN (4) WHEN ((review_rating = '3.0 out of 5 stars')) THEN (3) WHEN ((review_rating = '2.0 out of 5 stars')) THEN (2) WHEN ((review_rating = '1.0 out of 5 stars')) THEN (1) ELSE NULL END), 1)
# 0                                                4.5

# %% [markdown]
# The overall rating is 4.5/5

# %%
df_7 = _deepnote_execute_sql('select helpful_count,\n        review_title,\n        review_text\nfrom df\nwhere helpful_count like \'5,___ people found this helpful\'', 'SQL_DEEPNOTE_DATAFRAME_SQL')
df_7
# Out:
#                      helpful_count  \
# 0  5,087 people found this helpful
# 1  5,087 people found this helpful
#
#                                         review_title review_text
# 0  Which iPhone you should Purchase ? iPhone 8, X...       NOTE:
# 1  Which iPhone you should Purchase ? iPhone 8, X...       NOTE:

# %%
df_8 = _deepnote_execute_sql('select review_text\nfrom df\nwhere review_text like \'%expensive%\'', 'SQL_DEEPNOTE_DATAFRAME_SQL')
df_8
# Out:
#                                           review_text
# 0   Face recognition is slower some times. I have ...
# 1   I’ve been using Android for close to a decade ...
# 2   In my initial review, I said that the iPhone X...
# 3   Easy to use, serves the purpose. I was an andr...
# 4   I still don’t understand why people are crazy ...
# 5   This is my third iPhone and I must say - each ...
# 6   Display 3.7/5 — but u will get use too it not ...
# 7   Happy with the phone, initially I was scared t...
# 8   Not a value for money product.Apple is still g...
# 9   This phone is kind of the best iPhone in terms...
# 10  Everything is perfect,after all its apple ,but...
# 11                                      Too expensive
# 12  iPhone XR is a expensive branded phone and it’...
# 13  I felt just one thing of apple is its worth bu...
# 14  Nice product but no discount made the deal bit...
# 15                         Overall good and expensive
# ...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=ff5391e8-3f17-4774-a0a6-79b2a2e967de' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
